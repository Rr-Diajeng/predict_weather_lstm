# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('testset.csv')

# %%
df.head()
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# 0     5.0    280.0    West       NaN           NaN      7.4
# 1     NaN      0.0   North       NaN           NaN      NaN
# 2     NaN      0.0   North       NaN           NaN      NaN
# 3     2.0      0.0   North       NaN           NaN      NaN
# 4     1.2      0.0   North       NaN           NaN      0.0

# %%
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.rstrip()
df.head()
# Out:
#      datetime_utc _conds  _dewptm  _fog  _hail  _heatindexm  _hum  _precipm  \
# 0  19961101-11:00  Smoke      9.0     0      0          NaN  27.0       NaN
# 1  19961101-12:00  Smoke     10.0     0      0          NaN  32.0       NaN
# 2  19961101-13:00  Smoke     11.0     0      0          NaN  44.0       NaN
# 3  19961101-14:00  Smoke     10.0     0      0          NaN  41.0       NaN
# 4  19961101-16:00  Smoke     11.0     0      0          NaN  47.0       NaN
#
#    _pressurem  _rain  _snow  _tempm  _thunder  _tornado  _vism  _wdird _wdire  \
# 0      1010.0      0      0    30.0         0         0    5.0   280.0   West
# 1     -9999.0      0      0    28.0         0         0    NaN     0.0  North
# 2     -9999.0      0      0    24.0         0         0    NaN     0.0  North
# 3      1010.0      0      0    24.0         0         0    2.0     0.0  North
# 4      1011.0      0      0    23.0         0         0    1.2     0.0  North
#
#    _wgustm  _windchillm  _wspdm
# 0      NaN          NaN     7.4
# 1      NaN          NaN     NaN
# 2      NaN          NaN     NaN
# 3      NaN          NaN     NaN
# 4      NaN          NaN     0.0

# %%
plt.figure(figsize=(15, 10))
sns.histplot(df._tempm, bins=[i for i in range(0, 61, 5)], kde=False)
plt.title('distribution of temperatures')
plt.grid()
plt.show()

# %%
df.index = pd.to_datetime(df.datetime_utc)
df.head()
# Out:
#                        datetime_utc _conds  _dewptm  _fog  _hail  _heatindexm  \
# datetime_utc
# 1996-11-01 11:00:00  19961101-11:00  Smoke      9.0     0      0          NaN
# 1996-11-01 12:00:00  19961101-12:00  Smoke     10.0     0      0          NaN
# 1996-11-01 13:00:00  19961101-13:00  Smoke     11.0     0      0          NaN
# 1996-11-01 14:00:00  19961101-14:00  Smoke     10.0     0      0          NaN
# 1996-11-01 16:00:00  19961101-16:00  Smoke     11.0     0      0          NaN
#
#                      _hum  _precipm  _pressurem  _rain  _snow  _tempm  \
# datetime_utc
# 1996-11-01 11:00:00  27.0       NaN      1010.0      0      0    30.0
# 1996-11-01 12:00:00  32.0       NaN     -9999.0      0      0    28.0
# 1996-11-01 13:00:00  44.0       NaN     -9999.0      0      0    24.0
# 1996-11-01 14:00:00  41.0       NaN      1010.0      0      0    24.0
# 1996-11-01 16:00:00  47.0       NaN      1011.0      0      0    23.0
#
#                      _thunder  _tornado  _vism  _wdird _wdire  _wgustm  \
# datetime_utc
# 1996-11-01 11:00:00         0         0    5.0   280.0   West      NaN
# 1996-11-01 12:00:00         0         0    NaN     0.0  North      NaN
# 1996-11-01 13:00:00         0         0    NaN     0.0  North      NaN
# 1996-11-01 14:00:00         0         0    2.0     0.0  North      NaN
# 1996-11-01 16:00:00         0         0    1.2     0.0  North      NaN
#
#                      _windchillm  _wspdm
# datetime_utc
# 1996-11-01 11:00:00          NaN     7.4
# 1996-11-01 12:00:00          NaN     NaN
# 1996-11-01 13:00:00          NaN     NaN
# 1996-11-01 14:00:00          NaN     NaN
# 1996-11-01 16:00:00          NaN     0.0

# %%
#filter the columns by only the required columns

required_cols = ['_dewptm', '_fog', '_hail', '_hum', '_rain', '_snow', '_tempm', '_thunder', '_tornado']
df = df[required_cols]
df.head()
# Out:
#                      _dewptm  _fog  _hail  _hum  _rain  _snow  _tempm  \
# datetime_utc
# 1996-11-01 11:00:00      9.0     0      0  27.0      0      0    30.0
# 1996-11-01 12:00:00     10.0     0      0  32.0      0      0    28.0
# 1996-11-01 13:00:00     11.0     0      0  44.0      0      0    24.0
# 1996-11-01 14:00:00     10.0     0      0  41.0      0      0    24.0
# 1996-11-01 16:00:00     11.0     0      0  47.0      0      0    23.0
#
#                      _thunder  _tornado
# datetime_utc
# 1996-11-01 11:00:00         0         0
# 1996-11-01 12:00:00         0         0
# 1996-11-01 13:00:00         0         0
# 1996-11-01 14:00:00         0         0
# 1996-11-01 16:00:00         0         0

# %%
#check number of nan values in dataframe

df.isna().sum()
# Out:
# _dewptm     621
# _fog          0
# _hail         0
# _hum        757
# _rain         0
# _snow         0
# _tempm      673
# _thunder      0
# _tornado      0
# dtype: int64

# %%
#fill the nan values by upper row value
df = df.fillna(method='ffill')
df.tail
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10696\3147772463.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')
# <bound method NDFrame.tail of                      _dewptm  _fog  _hail  _hum  _rain  _snow  _tempm  \
# datetime_utc
# 1996-11-01 11:00:00      9.0     0      0  27.0      0      0    30.0
# 1996-11-01 12:00:00     10.0     0      0  32.0      0      0    28.0
# 1996-11-01 13:00:00     11.0     0      0  44.0      0      0    24.0
# 1996-11-01 14:00:00     10.0     0      0  41.0      0      0    24.0
# 1996-11-01 16:00:00     11.0     0      0  47.0      0      0    23.0
# ...                      ...   ...    ...   ...    ...    ...     ...
# 2017-04-24 06:00:00     17.0     0      0  25.0      0      0    34.0
# 2017-04-24 09:00:00     14.0     0      0  16.0      0      0    38.0
# 2017-04-24 12:00:00     12.0     0      0  14.0      0      0    36.0
# 2017-04-24 15:00:00     15.0     0      0  27.0      0      0    32.0
# 2017-04-24 18:00:00     15.0     0      0  30.0      0      0    30.0
#
#                      _thunder  _tornado
# datetime_utc
# 1996-11-01 11:00:00         0         0
# 1996-11-01 12:00:00         0         0
# 1996-11-01 13:00:00         0         0
# 1996-11-01 14:00:00         0         0
# 1996-11-01 16:00:00         0         0
# ...                       ...       ...
# 2017-04-24 06:00:00         0         0
# 2017-04-24 09:00:00         0         0
# 2017-04-24 12:00:00         0         0
# 2017-04-24 15:00:00         0         0
# 2017-04-24 18:00:00         0         0
#
# [100990 rows x 9 columns]>

# %%
# ambil mean per hari
df_final = df.resample('D').mean()
df_final.head()
# Out:
#                 _dewptm  _fog  _hail       _hum  _rain  _snow     _tempm  \
# datetime_utc
# 1996-11-01    11.666667   0.0    0.0  52.916667    0.0    0.0  22.333333
# 1996-11-02    10.458333   0.0    0.0  48.625000    0.0    0.0  22.916667
# 1996-11-03    12.041667   0.0    0.0  55.958333    0.0    0.0  21.791667
# 1996-11-04    10.222222   0.0    0.0  48.055556    0.0    0.0  22.722222
# 1996-11-05     8.200000   0.0    0.0  29.400000    0.0    0.0  27.800000
#
#               _thunder  _tornado
# datetime_utc
# 1996-11-01         0.0       0.0
# 1996-11-02         0.0       0.0
# 1996-11-03         0.0       0.0
# 1996-11-04         0.0       0.0
# 1996-11-05         0.0       0.0

# %%
df_final.isna().sum()
# Out:
# _dewptm     141
# _fog        141
# _hail       141
# _hum        141
# _rain       141
# _snow       141
# _tempm      141
# _thunder    141
# _tornado    141
# dtype: int64

# %%
df_final = df_final.fillna(method='ffill')
df_final.isna().sum()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10696\3141159991.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_final = df_final.fillna(method='ffill')
# _dewptm     0
# _fog        0
# _hail       0
# _hum        0
# _rain       0
# _snow       0
# _tempm      0
# _thunder    0
# _tornado    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df_final)

# Define sequence length and features
sequence_length = 10  # Number of time steps in each sequence
num_features = len(df_final.columns)

# Create sequences and corresponding labels
sequences = []
labels = []
for i in range(len(scaled_data) - sequence_length):
    seq = scaled_data[i:i+sequence_length]
    label = scaled_data[i+sequence_length][6]  # '_tempm' column index
    sequences.append(seq)
    labels.append(label)

# Convert to numpy arrays
sequences = np.array(sequences)
labels = np.array(labels)

# Split into train and test sets
train_size = int(0.8 * len(sequences))
train_x, test_x = sequences[:train_size], sequences[train_size:]
train_y, test_y = labels[:train_size], labels[train_size:]

print("Train X shape:", train_x.shape)
print("Train Y shape:", train_y.shape)
print("Test X shape:", test_x.shape)
print("Test Y shape:", test_y.shape)
# Out:
# Train X shape: (5976, 10, 9)
# Train Y shape: (5976,)
# Test X shape: (1494, 10, 9)
# Test Y shape: (1494,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Create the LSTM model
model = Sequential()

# Add LSTM layers with dropout
model.add(LSTM(units=128, input_shape=(train_x.shape[1], train_x.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=32, return_sequences=False))
model.add(Dropout(0.2))

# Add a dense output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\admin\diajeng\ta\predict_weather_lstm\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 128)        │        70,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 10, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 132,513 (517.63 KB)
#  Trainable params: 132,513 (517.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    train_x, train_y,
    epochs=100,
    batch_size=64,
    validation_split=0.2,  # Use part of the training data as validation
)
# Out:
# Epoch 1/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0871 - val_loss: 0.0046
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - val_loss: 0.0044
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0093 - val_loss: 0.0043
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0088 - val_loss: 0.0040
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - val_loss: 0.0046
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0086 - val_loss: 0.0039
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0081 - val_loss: 0.0038
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0073 - val_loss: 0.0042
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0077 - val_loss: 0.0035
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0071 - val_loss: 0.0041
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0067 - val_loss: 0.0037
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0070 - val_loss: 0.0032
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - val_loss: 0.0032
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - val_loss: 0.0031
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0058 - val_loss: 0.0029
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0057 - val_loss: 0.0029
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 0.0030
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - val_loss: 0.0025
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - val_loss: 0.0023
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - val_loss: 0.0023
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0026 - val_loss: 0.0021

# %%
model.save('my_lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

# Evaluate the best model on the test set
best_model = tf.keras.models.load_model('my_lstm_model.h5')
test_loss = best_model.evaluate(test_x, test_y)
print("Test Loss:", test_loss)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Test Loss: 0.0019767843186855316

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming you have trained the model and have the 'best_model' object
# Also, 'test_x' and 'test_y' should be available

# Predict temperatures using the trained model
predictions = best_model.predict(test_x)

# Calculate evaluation metrics
mae = mean_absolute_error(test_y, predictions)
mse = mean_squared_error(test_y, predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Mean Absolute Error (MAE): 0.0338388808366885
# Mean Squared Error (MSE): 0.0019767844919785582
# Root Mean Squared Error (RMSE): 0.04446104465685167

# %%
# y_true values
test_y_copies = np.repeat(test_y.reshape(-1, 1), test_x.shape[-1], axis=-1)
true_temp = scaler.inverse_transform(test_y_copies)[:,6]

# predicted values
prediction = best_model.predict(test_x)
prediction_copies = np.repeat(prediction, 9, axis=-1)
predicted_temp = scaler.inverse_transform(prediction_copies)[:,6]
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Plotting predicted and actual temperatures
plt.figure(figsize=(10, 6))
plt.plot(df_final.index[-100:], true_temp[-100:], label='Actual')
plt.plot(df_final.index[-100:], predicted_temp[-100:], label='Predicted')
plt.title('Temperature Prediction vs Actual')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.show()
